# %% [markdown]
# <a href="https://colab.research.google.com/github/thevedantt/UtubeChat/blob/main/UtubeChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yt_dlp
import google.generativeai as genai

# 🔐 Configure Gemini API
genai.configure(api_key="")
model = genai.GenerativeModel("gemini-2.0-flash")
chat = model.start_chat(history=[])

# 📥 Get video link
link = input("🔗 Enter the YouTube video link: ")

try:
    # 📦 Extract info using yt_dlp
    ydl_opts = {
        'quiet': True,
        'skip_download': True,
        'force_generic_extractor': False,
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(link, download=False)

    title = info.get("title", "N/A")
    views = info.get("view_count", "N/A")
    duration = info.get("duration", "N/A")
    rating = info.get("average_rating", "N/A")
    description = info.get("description", "No description found.")

    print("\n--- Video Details ---")
    print("📌 Title      :", title)
    print("👁️  Views     :", views)
    print("⏱️  Duration  :", duration, "seconds")
    print("⭐ Rating     :", rating)
    print("\n📝 Description:\n", description)

    # 💬 Start interactive Q&A based on description
    print("\n💡 You can now ask questions about the video description.")
    print("Type 'exit' to stop chatting.\n")

    chat.send_message(f"You are an AI tutor. Here's a YouTube video description:\n\n{description}\n\nUse this as reference to answer upcoming questions.")

    while True:
        query = input("You: ")
        if query.lower() == "exit":
            print("👋 Exiting chat.")
            break

        response = chat.send_message(query)
        print("🤖 Gemini:", response.text)

except Exception as e:
    print("❌ An error occurred:", str(e))
# Out:
# 🔗 Enter the YouTube video link: https://www.youtube.com/watch?v=vLqTf2b6GZw
#
# --- Video Details ---
# 📌 Title      : Python Tutorial for Beginners | Learn Python in 1.5 Hours
# 👁️  Views     : 11057875
# ⏱️  Duration  : 4632 seconds
# ⭐ Rating     : None
#
# 📝 Description:
#  This video is made with a lot of love from Apna College ❤️
#
# Are you worried about placements/internships? Want to prepare for companies like Microsoft, Amazon & Google? Join ALPHA Plus.
# 🔴 Alpha Placement Batch - https://bit.ly/3ELJjn2
#
#
# 🔥For (Window Users) download PyScripter - https://rb.gy/bvnn69 - Free & Open Source
# Download Python - (https://www.python.org/) (Windows & Mac)
#
# Note - This video shows installation of 2 Python editors, both are free to use. For window users I have downloaded PyScripter in this video.
#
# Link to the Notes - https://drive.google.com/drive/folders/1wfNTKinBAV6CCxaI5lfSnnRFAYpy0uEl?usp=share_link
#
# Join the Apni Community🔥 : https://telegram.me/+k4rdgTPwmm5kMGVl
# ...
